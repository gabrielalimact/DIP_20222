# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielalimact/DIP_20222/blob/main/image_stitching/image_stitching_dpi_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Implemente ```image stitching``` on images ['ic1.png', 'ic2.png', 'ic3.png', 'ic4.png'] to generate one panorama image 'ic.png'.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
read_images = ['./ic1.jpg', './ic2.jpg', './ic3.jpg', './ic4.jpg']
imgs = [cv2.imread(img) for img in read_images]


# Definir o objeto stitcher
stitcher = cv2.Stitcher_create()

# Criar a imagem panorâmica
status, pano = stitcher.stitch(imgs)

# %%
saving = cv2.imwrite('ic.png', cv2.cvtColor(pano, cv2.COLOR_BGR2RGB))
result = cv2.imread('./ic.png')

# %%
plt.imshow(result)
